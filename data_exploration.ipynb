# %%
import requests
def fetch_data_from_ndc_api(api_url, limit=5):
    """
    Fetch data from the FDA NDC API endpoint.

    Args:
        api_url (str): The URL of the API endpoint.
    """

    try:
        response = requests.get(api_url, params={"limit": limit})
        response.raise_for_status()  # Raise an error for bad responses (4xx or 5xx)
        data = response.json()  # Parse the JSON response
        return data
    except requests.exceptions.RequestException as e:
        print(f"An error occurred while fetching data from the API: {e}")
        return None

# %%
import json
api_url = "https://api.fda.gov/drug/ndc.json"
data = fetch_data_from_ndc_api(api_url)
print(json.dumps(data, indent=2))
# Out:
# {
#   "meta": {
#     "disclaimer": "Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.",
#     "terms": "https://open.fda.gov/terms/",
#     "license": "https://open.fda.gov/license/",
#     "last_updated": "2026-08-14",
#     "results": {
#       "skip": 0,
#       "limit": 5,
#       "total": 137016
#     }
#   },
#   "results": [
#     {
#       "product_ndc": "0955-1057",
#       "generic_name": "Sevelamer Carbonate",
#       "labeler_name": "Sanofi-Aventis U.S. LLC",
#       "brand_name": "Sevelamer Carbonate",
#       "active_ingredients": [
#         {
#           "name": "SEVELAMER CARBONATE",
#           "strength": "800 mg/1"
#         }
#       ],
#       "finished": true,
#       "packaging": [
#         {
#           "package_ndc": "0955-1057-30",
#           "description": "270 TABLET, FILM COATED in 1 BOTTLE (0955-1057-30)",
#           "marketing_start_date": "20230714",
#           "sample": false
#         }
#       ],
#       "listing_expiration_date": "20261231",
#       "openfda": {
#         "manufacturer_name": [
#           "Sanofi-Aventis U.S. LLC"
#         ],
#         "rxcui": [
#           "749206",
#           "861370",
#           "861375"
#         ],
#         "spl_set_id": [
#           "3abc32fe-1bfc-4759-8f7c-36095e221b06"
#         ],
#         "is_original_packager": [
#           true
#         ],
#         "unii": [
#           "9YCX42I8IU"
#         ]
#       },
#       "marketing_category": "NDA AUTHORIZED GENERIC",
#       "dosage_form": "TABLET, FILM COATED",
#       "spl_id": "42bdb389-5550-487c-aed2-c4e3afd239c8",
#       "product_type": "HUMAN PRESCRIPTION DRUG",
#       "route": [
#         "ORAL"
#       ],
#       "marketing_start_date": "20230714",
#       "product_id": "0955-1057_42bdb389-5550-487c-aed2-c4e3afd239c8",
#       "application_number": "NDA022127",
#       "brand_name_base": "Sevelamer Carbonate",
#       "pharm_class": [
#         "Phosphate Binder [EPC]",
#         "Phosphate Chelating Activity [MoA]"
#       ]
#     },
#     {
#       "product_ndc": "49574-523",
#       "generic_name": "Tofacitinib Citrate",
#       "labeler_name": "Hunan Jiudian Pharmaceutical Co.,Ltd.",
#       "active_ingredients": [
#         {
#           "name": "TOFACITINIB CITRATE",
#           "strength": "1 kg/kg"
#         }
#       ],
#       "finished": false,
#       "packaging": [
#         {
#           "package_ndc": "49574-523-01",
#           "description": "2 kg in 1 BAG (49574-523-01)",
#           "marketing_start_date": "11-AUG-21"
#         }
#       ],
#       "listing_expiration_date": "20261231",
#       "openfda": {},
#       "marketing_category": "BULK INGREDIENT",
#       "dosage_form": "POWDER",
#       "spl_id": "2a89977f-871d-d62c-e063-6294a90aed0a",
#       "product_type": "BULK INGREDIENT",
#       "marketing_start_date": "20210811",
#       "product_id": "49574-523_2a89977f-871d-d62c-e063-6294a90aed0a",
#       "brand_name_base": null
#     },
#     {
#       "product_ndc": "0990-7972",
#       "generic_name": "SODIUM CHLORIDE",
#       "labeler_name": "ICU Medical Inc.",
#       "brand_name": "Sodium Chloride",
#       "active_ingredients": [
#         {
#           "name": "SODIUM CHLORIDE",
#           "strength": "900 mg/100mL"
#         }
#       ],
#       "finished": true,
#       "packaging": [
#         {
#           "package_ndc": "0990-7972-08",
#           "description": "4 POUCH in 1 CASE (0990-7972-08)  / 1 BAG in 1 POUCH / 3000 mL in 1 BAG",
#           "marketing_start_date": "20190701",
#           "sample": false
#         }
#       ],
#       "listing_expiration_date": "20271231",
#       "openfda": {
#         "manufacturer_name": [
#           "ICU Medical Inc."
#         ],
#         "rxcui": [
#           "486515"
#         ],
#         "spl_set_id": [
#           "009bef3c-e8ac-46be-b564-a2556adf0081"
#         ],
#         "is_original_packager": [
#           true
#         ],
#         "unii": [
#           "451W47IQ8X"
#         ]
#       },
#       "marketing_category": "NDA",
#       "dosage_form": "IRRIGANT",
#       "spl_id": "6026dcec-3511-4ed6-9420-e9fcb6e0e335",
#       "product_type": "HUMAN PRESCRIPTION DRUG",
#       "route": [
#         "IRRIGATION"
#       ],
#       "marketing_start_date": "20190701",
#       "product_id": "0990-7972_6026dcec-3511-4ed6-9420-e9fcb6e0e335",
#       "application_number": "NDA018314",
#       "brand_name_base": "Sodium Chloride",
#       "pharm_class": [
#         "Increased Large Intestinal Motility [PE]",
#         "Inhibition Large Intestine Fluid/Electrolyte Absorption [PE]",
#         "Osmotic Activity [MoA]",
#         "Osmotic Laxative [EPC]"
#       ]
#     },
#     {
#       "product_ndc": "50580-001",
#       "generic_name": "Diphenhydramine hydrochloride",
#       "labeler_name": "Kenvue Brands LLC",
#       "active_ingredients": [
#         {
#           "name": "DIPHENHYDRAMINE HYDROCHLORIDE",
#           "strength": "25 mg/1"
#         }
#       ],
#       "finished": false,
#       "packaging": [
#         {
#           "package_ndc": "50580-001-01",
#           "description": "120000 TABLET, FILM COATED in 1 DRUM (50580-001-01)",
#           "marketing_start_date": "01-OCT-25"
#         },
#         {
#           "package_ndc": "50580-001-02",
#           "description": "1800000 TABLET, FILM COATED in 1 BAG (50580-001-02)",
#           "marketing_start_date": "01-OCT-25"
#         }
#       ],
#       "listing_expiration_date": "20261231",
#       "openfda": {},
#       "marketing_category": "DRUG FOR FURTHER PROCESSING",
#       "dosage_form": "TABLET, FILM COATED",
#       "spl_id": "23a53008-0ee3-6d49-e063-6394a90acfe7",
#       "product_type": "DRUG FOR FURTHER PROCESSING",
#       "marketing_start_date": "20251001",
#       "product_id": "50580-001_23a53008-0ee3-6d49-e063-6394a90acfe7",
#       "brand_name_base": null
#     },
#     {
#       "product_ndc": "51344-928",
#       "generic_name": "Bismuth subsalicylate",
#       "labeler_name": "MEDGEL PRIVATE LIMITED",
#       "active_ingredients": [
#         {
#           "name": "BISMUTH SUBSALICYLATE",
#           "strength": "262 mg/1"
#         }
#       ],
#       "finished": false,
#       "packaging": [
#         {
#           "package_ndc": "51344-928-00",
#           "description": "48 POUCH in 1 BOX (51344-928-00)  / 300 CAPSULE, LIQUID FILLED in 1 POUCH",
#           "marketing_start_date": "24-MAR-25"
#         }
#       ],
#       "listing_expiration_date": "20261231",
#       "openfda": {},
#       "marketing_category": "DRUG FOR FURTHER PROCESSING",
#       "dosage_form": "CAPSULE, LIQUID FILLED",
#       "spl_id": "cb06c32c-9518-4e6f-a3fb-49211ca6054a",
#       "product_type": "DRUG FOR FURTHER PROCESSING",
#       "marketing_start_date": "20250324",
#       "product_id": "51344-928_cb06c32c-9518-4e6f-a3fb-49211ca6054a",
#       "brand_name_base": null
#     }
#   ]
# }

# %%
import pandas as pd
def flatten_json(data):
    """
    Flatten JSON objects and arrays into a flat table.

    Args:
        data (dict): The JSON data to flatten.
    Returns:
        pd.DataFrame: A DataFrame containing the flattened data.
    """
    if not data:
        return None

    res = data['results']
    return res

# %%
results = flatten_json(json)
# Out:
# [{'product_ndc': '76420-085',
#   'generic_name': 'TRIAMCINOLONE ACETONIDE',
#   'labeler_name': 'Asclemed USA, Inc.',
#   'brand_name': 'KENALOG-40',
#   'active_ingredients': [{'name': 'TRIAMCINOLONE ACETONIDE',
#     'strength': '40 mg/mL'}],
#   'finished': 'true',
#   'packaging': [{'package_ndc': '76420-085-01',
#     'description': '1 mL in 1 VIAL, SINGLE-DOSE (76420-085-01)',
#     'marketing_start_date': '20200506',
#     'sample': 'false'}],
#   'listing_expiration_date': '20261231',
#   'openfda': {'manufacturer_name': ['Asclemed USA, Inc.'],
#    'rxcui': ['1085754', '1085756'],
#    'spl_set_id': ['0bc9c75f-963c-40b0-995b-dfcbd50371a5'],
#    'nui': ['N0000175576', 'N0000175450'],
#    'pharm_class_epc': ['Corticosteroid [EPC]'],
#    'pharm_class_moa': ['Corticosteroid Hormone Receptor Agonists [MoA]'],
#    'unii': ['F446C597KA']},
#   'marketing_category': 'NDA',
#   'dosage_form': 'INJECTION, SUSPENSION',
#   'spl_id': 'a4f97750-d5aa-8236-e053-2995a90a1854',
#   'product_type': 'HUMAN PRESCRIPTION DRUG',
#   'route': ['INTRA-ARTICULAR', 'INTRAMUSCULAR'],
#   'marketing_start_date': '20090601',
#   'product_id': '76420-085_a4f97750-d5aa-8236-e053-2995a90a1854',
#   'application_number': 'NDA014901',
#   'brand_name_base': 'KENALOG-40',
#   'pharm_class': ['Corticosteroid Hormone Receptor Agonists [MoA]',
#    'Corticosteroid [EPC]']}]
